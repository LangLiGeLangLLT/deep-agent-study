# %%
import os
from typing import Literal
from tavily import TavilyClient
from deepagents import create_deep_agent

from dotenv import load_dotenv

load_dotenv()

tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])


def internet_search(
    query: str,
    max_results: int = 5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )


# System prompt to steer the agent to be an expert researcher
research_instructions = """You are an expert researcher. Your job is to conduct thorough research and then write a polished report.

You have access to an internet search tool as your primary means of gathering information.

## `internet_search`

Use this to run an internet search for a given query. You can specify the max number of results to return, the topic, and whether raw content should be included.
"""

agent = create_deep_agent(
    model="openai:Qwen/Qwen3-8B",
    tools=[internet_search],
    system_prompt=research_instructions,
)

result = agent.invoke({"messages": [{"role": "user", "content": "What is langgraph?"}]})

# Print the agent's response
print(result["messages"][-1].content)
# Out:
# LangGraph is an open-source AI agent framework developed by LangChain. It enables the construction, deployment, and management of complex generative AI workflows. At its core, LangGraph employs graph-based architectures to model and manage the relationships between various components of an AI agent's workflow. This approach provides full transparency over the agent's state and actions, allowing users to better understand and control the process.
#
# Some key features and aspects of LangGraph include:
#
# 1. **Graph-Based Workflows**: LangGraph is designed to model AI agent workflows as graphs, where each node represents a specific component or step within the process. This allows for a flexible and structured way to manage workflows with complex logic and dependencies.
#
# 2. **State Management**: It emphasizes state tracking and management within workflows, enabling the agent to remember past actions and make decisions based on that information. This feature is crucial for building agent systems with memory persistence and context awareness.
#
# 3. **Human-in-the-Loop**: LangGraph supports an "interrupt" mechanism that allows human oversight and intervention. This is particularly useful for tasks that require feedback or decisions from users.
#
# 4. **Customizable Agent Architectures**: It offers tools for building and modifying agent architectures, making it adaptable to a wide range of applications and use cases.
#
# 5. **Integration with Models and Tools**: LangGraph allows users to integrate with various large language models and model providers, enabling the creation of customizable AI agents that can be used for specific tasks.
#
# 6. **Streaming and Observability**: It provides features like streaming intermediate steps and observability tools for debugging and monitoring agents in real-time.
#
# 7. **Documentation and Community**: LangGraph has comprehensive documentation and is actively maintained with a large community of contributors. It includes examples and tutorials to help developers get started with building their own AI agents.
#
# In summary, LangGraph is a powerful and flexible framework for designing, managing, and deploying complex AI workflows, especially in the context of generative AI agents.
