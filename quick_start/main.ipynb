# %%
import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

model = ChatOpenAI(
    model=os.getenv("LLM_MODEL_ID"),
    api_key=os.getenv("LLM_API_KEY"),
    base_url=os.getenv("LLM_BASE_URL"),
    temperature=0,
)

# %%
from typing import Literal
from tavily import TavilyClient
from deepagents import create_deep_agent


tavily_client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))


def internet_search(
    query: str,
    max_results: int = 5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )


# System prompt to steer the agent to be an expert researcher
research_instructions = """You are an expert researcher. Your job is to conduct thorough research and then write a polished report.

You have access to an internet search tool as your primary means of gathering information.

## `internet_search`

Use this to run an internet search for a given query. You can specify the max number of results to return, the topic, and whether raw content should be included.
"""

agent = create_deep_agent(
    model=model,
    tools=[internet_search],
    system_prompt=research_instructions,
)

result = agent.invoke({"messages": [{"role": "user", "content": "What is langgraph?"}]})

# Print the agent's response
print(result["messages"][-1].content)
# Out:
# **LangGraph** is an open-source AI agent framework created by [LangChain](https://www.langchain.com/) that helps developers build, deploy, and manage complex generative AI agent workflows.
#
# ## Key Features:
#
# **1. Graph-Based Architecture**
# - Uses nodes and edges to model AI workflows
# - **Nodes** represent individual components or agents within a workflow
# - **Edges** define the connections and flow between nodes
# - Provides full transparency of the agent's state throughout the workflow
#
# **2. Control and Orchestration**
# - Designed for scenarios where you need precise **control** over LLM application execution
# - Manages the flow of data and sequence of operations
# - Allows you to build applications that follow predictable processes while leveraging LLM capabilities
# - Ideal for multi-step workflows with decision points at each junction
#
# **3. Use Cases**
# - Chatbots that handle various types of user requests
# - Multi-agent systems that perform complex tasks
# - AI-powered customer support systems
# - Research systems that process complex data
# - Trading algorithms that analyze market trends
#
# **4. Developer Benefits**
# - Simplifies development of complex LLM applications
# - Provides structured framework for managing state
# - Coordinates agent interactions efficiently
# - Allows developers to focus on high-level logic rather than coordination intricacies
# - Includes LangGraph Studio, a visual development environment
#
# **In simple terms:** If LangChain is the engine for building LLM applications, LangGraph is the GPS that ensures your AI agents follow the right route through complex workflows. It's particularly valuable when you need to orchestrate a series of steps with specific decision-making at each point.
